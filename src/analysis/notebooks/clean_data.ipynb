# %%
import pandas as pd

# %%
df = pd.read_csv("../data/data.tsv", sep="\t")
df.head()
# Out:
#                                                  url  \
# 0  https://vkusvill.ru/goods/baklazhany-po-sychua...
# 1  https://vkusvill.ru/goods/borshch-s-govyadinoy...
# 2  https://vkusvill.ru/goods/fetuchini-s-kuritsey...
# 3  https://vkusvill.ru/goods/kotleta-kurinaya-s-f...
# 4  https://vkusvill.ru/goods/kotleta-kurinaya-s-k...
#
#                                   name  price_rub  weight_g  kcal_per_100g  \
# 0       Баклажаны по-сычуаньски, 200 г      278.0     200.0          227.1
# 1                     Борщ с говядиной      218.0     390.0           33.0
# 2       Фетучини с курицей и лисичками      328.0     220.0          165.4
# 3           Котлета куриная с фарфалле      246.0     200.0          203.1
# 4  Котлета куриная с картофельным пюре      280.0     250.0          155.0
#
#    proteins_g_per_100g  fats_g_per_100g  carbs_g_per_100g  shelf_life_days  \
# 0                  1.4             15.9              19.6              4.0
# ...

# %%
df[df["weight_g"].isnull()]
# Out:
#                                                    url  \
# 390  https://vkusvill.ru/goods/yaytsa-perepelinye-k...
# 504  https://vkusvill.ru/goods/yaytsa-kurinye-kopch...
#
#                                        name  price_rub  weight_g  \
# 390  Яйца перепелиные копченые "Молодецкие"      305.0       NaN
# 504      Яйца куриные копченые "Молодецкие"      205.0       NaN
#
#      kcal_per_100g  proteins_g_per_100g  fats_g_per_100g  carbs_g_per_100g  \
# 390          165.8                 12.0             13.0               0.2
# 504          150.9                 14.8              9.7               1.1
#
#      shelf_life_days  storage_temp_min_c  ...  category_main  \
# 390             17.0                 2.0  ...        Закуски
# 504             17.0                 0.0  ...           Яйцо
#
#                       category_path     brand   country  \
# 390           Готовая еда / Закуски  ВкусВилл    Россия
# 504  Молочные продукты, яйцо / Яйцо       NaN  Беларусь
#
# ...

# %%
df = df.drop(df[df["weight_g"].isnull()].index)

# %%
df.isnull().sum()
# Out:
# url                      0
# name                     0
# price_rub                0
# weight_g                 0
# kcal_per_100g            9
# proteins_g_per_100g      8
# fats_g_per_100g          9
# carbs_g_per_100g        21
# shelf_life_days          0
# storage_temp_min_c       5
# storage_temp_max_c       5
# category_main            1
# category_path            1
# brand                    3
# country                  0
# manufacturer           199
# rating                  18
# ratings_count           18
# ingredients              0
# tags                     3
# image_path               0
# dtype: int64

# %%
df[df["kcal_per_100g"].isnull()]
# Out:
#                                                    url  \
# 217  https://vkusvill.ru/goods/chiabatta-s-tuntsom-...
# 841  https://vkusvill.ru/goods/assorti-gunkanov-s-k...
# 913  https://vkusvill.ru/goods/assorti-iz-sushi-s-k...
# 914  https://vkusvill.ru/goods/blin-s-forelyu-slivo...
# 933  https://vkusvill.ru/goods/set-filadelfiya-1115...
# 934  https://vkusvill.ru/goods/set-rollov-filadelfi...
# 961  https://vkusvill.ru/goods/assorti-iz-sushi-i-g...
# 964  https://vkusvill.ru/goods/blin-tsezar-kafe-963...
# 981    https://vkusvill.ru/goods/set-unagi-111559.html
#
#                                                 name  price_rub  weight_g  \
# 217                  Чиабатта с тунцом и яйцом, кафе      264.0     180.0
# 841    Ассорти гунканов с креветками, семгой и угрем      690.0     240.0
# 913    Ассорти из суши с креветками, лососем и угрём      650.0     185.0
# 914  Блин с форелью, сливочным сыром и руколой, кафе      380.0     204.0
# ...

# %%
df = df.dropna(subset=["kcal_per_100g"])

# %%
df.isnull().sum()
# Out:
# url                      0
# name                     0
# price_rub                0
# weight_g                 0
# kcal_per_100g            0
# proteins_g_per_100g      0
# fats_g_per_100g          1
# carbs_g_per_100g        13
# shelf_life_days          0
# storage_temp_min_c       5
# storage_temp_max_c       5
# category_main            1
# category_path            1
# brand                    3
# country                  0
# manufacturer           196
# rating                  18
# ratings_count           18
# ingredients              0
# tags                     3
# image_path               0
# dtype: int64

# %%
df.loc[df["carbs_g_per_100g"].isnull(), "carbs_g_per_100g"] = 0
df.loc[df["fats_g_per_100g"].isnull(), "fats_g_per_100g"] = 0

# %%
df.isnull().sum()
# Out:
# url                      0
# name                     0
# price_rub                0
# weight_g                 0
# kcal_per_100g            0
# proteins_g_per_100g      0
# fats_g_per_100g          0
# carbs_g_per_100g         0
# shelf_life_days          0
# storage_temp_min_c       5
# storage_temp_max_c       5
# category_main            1
# category_path            1
# brand                    3
# country                  0
# manufacturer           196
# rating                  18
# ratings_count           18
# ingredients              0
# tags                     3
# image_path               0
# dtype: int64

# %%
df.loc[df["storage_temp_min_c"].isnull(), "storage_temp_min_c"] = df["storage_temp_min_c"].median()
df.loc[df["storage_temp_max_c"].isnull(), "storage_temp_max_c"] = df["storage_temp_max_c"].median()

# %%
df.isnull().sum()
# Out:
# url                      0
# name                     0
# price_rub                0
# weight_g                 0
# kcal_per_100g            0
# proteins_g_per_100g      0
# fats_g_per_100g          0
# carbs_g_per_100g         0
# shelf_life_days          0
# storage_temp_min_c       0
# storage_temp_max_c       0
# category_main            1
# category_path            1
# brand                    3
# country                  0
# manufacturer           196
# rating                  18
# ratings_count           18
# ingredients              0
# tags                     3
# image_path               0
# dtype: int64

# %%
df.loc[df["category_main"].isnull(), "category_main"] = ""
df.loc[df["category_path"].isnull(), "category_path"] = ""

# %%
df.isnull().sum()
# Out:
# url                      0
# name                     0
# price_rub                0
# weight_g                 0
# kcal_per_100g            0
# proteins_g_per_100g      0
# fats_g_per_100g          0
# carbs_g_per_100g         0
# shelf_life_days          0
# storage_temp_min_c       0
# storage_temp_max_c       0
# category_main            0
# category_path            0
# brand                    3
# country                  0
# manufacturer           196
# rating                  18
# ratings_count           18
# ingredients              0
# tags                     3
# image_path               0
# dtype: int64

# %%
df.loc[df["brand"].isnull(), "brand"] = df["brand"].mode()[0]

# %%
df.isnull().sum()
# Out:
# url                      0
# name                     0
# price_rub                0
# weight_g                 0
# kcal_per_100g            0
# proteins_g_per_100g      0
# fats_g_per_100g          0
# carbs_g_per_100g         0
# shelf_life_days          0
# storage_temp_min_c       0
# storage_temp_max_c       0
# category_main            0
# category_path            0
# brand                    0
# country                  0
# manufacturer           196
# rating                  18
# ratings_count           18
# ingredients              0
# tags                     3
# image_path               0
# dtype: int64

# %%
df.loc[df["rating"].isnull()]
# Out:
#                                                    url  \
# 90   https://vkusvill.ru/goods/shchupaltsa-kalmarov...
# 122  https://vkusvill.ru/goods/bliny-shokoladnye-s-...
# 166  https://vkusvill.ru/goods/zapekanka-tvorozh-s-...
# 237  https://vkusvill.ru/goods/zapekanka-klassiches...
# 539  https://vkusvill.ru/goods/zapekanka-tvorozhnay...
# 565  https://vkusvill.ru/goods/bliny-s-vetchinoy-i-...
# 568  https://vkusvill.ru/goods/govyadina-tomlenaya-...
# 579  https://vkusvill.ru/goods/shnitsel-kurinyy-480...
# 642  https://vkusvill.ru/goods/kombo-losos-file-s-k...
# 643  https://vkusvill.ru/goods/kombo-losos-file-s-k...
# 644  https://vkusvill.ru/goods/kombo-sibas-na-grile...
# 769  https://vkusvill.ru/goods/kombo-losos-steyk-s-...
# 772  https://vkusvill.ru/goods/roll-snezhnaya-kalif...
# 822  https://vkusvill.ru/goods/bitochki-morkovnye-4...
# 839  https://vkusvill.ru/goods/vaflya-sendvich-s-ve...
# 948  https://vkusvill.ru/goods/krem-sup-iz-brokkoli...
# ...

# %%
df.loc[df["rating"].isnull(), "rating"] = 0
df.loc[df["ratings_count"].isnull(), "ratings_count"] = 0

# %%
df.isnull().sum()
# Out:
# url                      0
# name                     0
# price_rub                0
# weight_g                 0
# kcal_per_100g            0
# proteins_g_per_100g      0
# fats_g_per_100g          0
# carbs_g_per_100g         0
# shelf_life_days          0
# storage_temp_min_c       0
# storage_temp_max_c       0
# category_main            0
# category_path            0
# brand                    0
# country                  0
# manufacturer           196
# rating                   0
# ratings_count            0
# ingredients              0
# tags                     3
# image_path               0
# dtype: int64

# %%
df.to_csv("../data/data_clean.tsv", sep="\t", index=False)
